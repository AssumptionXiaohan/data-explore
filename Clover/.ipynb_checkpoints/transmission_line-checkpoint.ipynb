# %%
import os

import numpy as np
import pandas as pd
import geopandas as gpd
import rasterio as rio
from rasterio.plot import plotting_extent ## geotiff plotting

import matplotlib.pyplot as plt

# %%
## ca shapefile
datapath = 'data/CA_Counties'
ca = gpd.read_file(datapath).to_crs(epsg=4326)

## us shapefile
datapath = 'data/states_21basic'
us = gpd.read_file(datapath).to_crs(epsg=4326)
usa = us[(us['STATE_NAME'] != 'Hawaii') & (us['STATE_NAME'] != 'Alaska')]

# %% [markdown]
# # Electric Transmission Line

# %%
cetl_file = 'California_Electric_Transmission_Line/'
cetl_shp = gpd.read_file(cetl_file)
with pd.option_context("display.max_rows", 4):
    display(cetl_shp)
# Out:
#       OBJECTID         Name   kV  kV_Sort  Owner       Status Circuit Type  \
# 0         1001   PG&E 115kV  115    115.0   PG&E  Operational  Single   OH
# 1         1002   PG&E 115kV  115    115.0   PG&E  Operational  Single   OH
# ...        ...          ...  ...      ...    ...          ...     ...  ...
# 6839      6840  PCORP 115kV  115    115.0  PCORP  Operational  Single   OH
# 6840      6841   PCORP 69kV   69     69.0  PCORP  Operational  Single   OH
#
#                Legend  Length_Mil      Length_Fee Comments    Shape__Len  \
# 0          PG&E_115kV         6.0  33268.72239225     None  13066.802944
# 1          PG&E_115kV         0.0    557.27733333     None    218.746290
# ...               ...         ...             ...      ...           ...
# 6839  PCORP_110_115kV        15.0  79429.59073287     None  32355.604619
# 6840    PCORP_60_69kV         6.0  31570.79147607     None  12878.622817
#
#                                                geometry
# 0     LINESTRING (-121.54456 39.07029, -121.54687 39...
# 1     LINESTRING (-121.54261 39.07048, -121.54285 39...
# ...                                                 ...
# 6839  LINESTRING (-122.36031 41.71152, -122.36062 41...
# 6840  LINESTRING (-122.63027 41.72868, -122.62962 41...
#
# [6841 rows x 14 columns]

# %%
cetl = cetl_shp.to_crs(epsg=4326)
# geometry
cetl.geometry
# Out:
# 0       LINESTRING (-121.54456 39.07029, -121.54687 39...
# 1       LINESTRING (-121.54261 39.07048, -121.54285 39...
# 2       LINESTRING (-121.54260 39.07029, -121.54285 39...
# 3       LINESTRING (-121.48641 39.53277, -121.49006 39...
# 4       LINESTRING (-123.16468 39.17065, -123.16532 39...
#                               ...
# 6836    LINESTRING (-123.82829 40.82050, -123.82839 40...
# 6837    LINESTRING (-120.27396 37.18498, -120.27635 37...
# 6838    LINESTRING (-120.19425 40.30042, -120.19471 40...
# 6839    LINESTRING (-122.36031 41.71152, -122.36062 41...
# 6840    LINESTRING (-122.63027 41.72868, -122.62962 41...
# Name: geometry, Length: 6841, dtype: geometry

# %%
# plot map and transmission line
fig, ax = plt.subplots(figsize = (20, 20))
ca.plot(ax = ax, cmap = 'Greys', alpha = 0.5)
cetl.geometry.plot(ax = ax,cmap = 'Blues')

# add fire
fire_file = 'data/shapefile/ca_2.shp'
fire_shp = gpd.read_file(fire_file)

## geopandas selection (select year=2010)
shp_selected = fire_shp[fire_shp.loc[:, 'year'] >= 2010]
shp_selected.plot(ax=ax,cmap ='Reds')

# %% [markdown]
# # California Electric Substation

# %%
ces_file = 'California_Electric_Substation/'
ces_shp = gpd.read_file(ces_file)
with pd.option_context("display.max_rows", 4):
    display(ces_shp)
ces = ces_shp.to_crs(epsg=4326)
# Out:
#       OBJECTID Substation   Substati_1 Alias       Status  Owner Map_Owner  \
# 0            1     SS0003       Jenney  None  Operational  Other     Other
# 1            2     SS0004       Corona  None  Operational   PG&E      PG&E
# ...        ...        ...          ...   ...          ...    ...       ...
# 3259      3260     SS3648  Dave Bakkie  None  Operational  Other     Other
# 3260      3261     SS3649   South East  None  Operational  Other     Other
#
#      Map_Part Engineerin kV_12_TO_3  ... kV_220_To_ kV_345_To_ kV_500_DC  \
# 0           M       None        YES  ...       None       None      None
# 1           M       None       None  ...       None       None      None
# ...       ...        ...        ...  ...        ...        ...       ...
# 3259        M       None       None  ...       None       None      None
# 3260        M       None       None  ...       None       None      None
#
#           Highest_kV Postal_Cit   County Zip_Code State Comments  \
# 0     110kV to 161kV    Alameda  Alameda    94501    CA     None
# 1     110kV to 161kV   Petaluma   Sonoma    94954    CA     None
# ...              ...        ...      ...      ...   ...      ...
# 3259    33kV to 92kV  Roseville   Placer    95747    CA     None
# 3260    33kV to 92kV  Roseville   Placer    95661    CA     None
#
#                          geometry
# 0     POINT (-122.24292 37.77244)
# 1     POINT (-122.65737 38.26501)
# ...                           ...
# 3259  POINT (-121.32861 38.80155)
# 3260  POINT (-121.23486 38.73823)
#
# [3261 rows x 22 columns]

# %%
fig, ax = plt.subplots(figsize = (20, 20))
ca.plot(ax = ax, cmap = 'Greys', alpha = 0.5)
ces.geometry.plot(ax = ax,cmap='Blues')
shp_selected.plot(ax=ax,cmap ='Reds')

# %%
with pd.option_context("display.max_rows", 4):
    display(fire_shp)
# Out:
#       fire_ID      lat      lon   size  perimeter  start_date  start_DOY  \
# 0          12  41.9062 -122.959   7.72      17.59  2016-08-31        244
# 1           8  41.8937 -122.974  20.37      40.74  2016-08-28        241
# ...       ...      ...      ...    ...        ...         ...        ...
# 4888    10562  41.6979 -120.170   0.21       1.85  2005-08-26        238
# 4889    10567  41.6854 -120.186   1.07       4.63  2005-08-17        229
#
#         end_date  end_DOY  duration  expansion  fire_line  speed  direction  \
# 0     2016-09-12      256        13       0.59       1.28   1.37          3
# 1     2016-09-12      256        16       1.27       2.66   1.49          8
# ...          ...      ...       ...        ...        ...    ...        ...
# 4888  2005-08-26      238         1       0.21       0.46   0.46          0
# 4889  2005-08-25      237         9       0.12       0.26   0.65          1
#
#      direction_  landcover                   landcover_ tile_ID  year  \
# 0          east          1  Evergreen Needleleaf forest  h08v04  2016
# 1     northwest          1  Evergreen Needleleaf forest  h08v04  2016
# ...         ...        ...                          ...     ...   ...
# 4888       none          0                        Water  h09v04  2005
# 4889      north          0                        Water  h09v04  2005
#
#                                                geometry
# 0     POLYGON ((-122.99102 41.93333, -122.97421 41.9...
# 1     POLYGON ((-123.02535 41.92500, -123.01975 41.9...
# ...                                                 ...
# 4888  POLYGON ((-120.17758 41.70000, -120.17200 41.7...
# 4889  POLYGON ((-120.19548 41.69167, -120.18433 41.6...
#
# [4890 rows x 20 columns]
